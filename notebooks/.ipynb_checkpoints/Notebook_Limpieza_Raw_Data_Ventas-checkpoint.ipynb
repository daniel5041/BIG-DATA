# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Cargar archivo Excel
df = pd.read_excel('../data/raw/Raw_Data_Ventas.xlsx')

# Mostrar primeras filas
df.head()
# Out:
#   IdVenta           FechaVenta ClienteId ClienteNombre          Ciudad  \
# 0  V-1001  2026-05-01 00:00:00      C001     Ana López     Tegucigalpa
# 1  V-1001  2026-05-01 00:00:00      C001     Ana López     Tegucigalpa
# 2  V-1002           01/05/2026      c002  Carlos Mejía  San Pedro Sula
# 3  V-1003           2026/05/02      C003  María Santos             SPS
# 4  V-1004         mayo 3, 2026      C004   Jose Rivera        La Ceiba
#
#   Producto   Categoria Cantidad PrecioUnitario Descuento     MetodoPago  \
# 0   Laptop  Tecnología        1          14500      0.05        Tarjeta
# 1   Laptop  Tecnología        1          14500      0.05        Tarjeta
# 2    mouse  tecnologia        2      L. 350.00         0       efectivo
# 3  Teclado  tecnologia        1         450,50        5%  Transferencia
# 4  Monitor  Tecnología        0           3200         0        Tarjeta
#
#       Estado   Vendedor              EmailCliente   Telefono  TotalReportado  \
# ...

# %%
# Mostrar información general del dataset
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   IdVenta               52 non-null     str
#  1   FechaVenta            51 non-null     object
#  2   ClienteId             51 non-null     str
#  3   ClienteNombre         51 non-null     str
#  4   Ciudad                51 non-null     str
#  5   Producto              52 non-null     str
#  6   Categoria             52 non-null     str
#  7   Cantidad              51 non-null     object
#  8   PrecioUnitario        51 non-null     object
#  9   Descuento             51 non-null     object
#  10  MetodoPago            52 non-null     str
#  11  Estado                51 non-null     str
#  12  Vendedor              52 non-null     str
#  13  EmailCliente          51 non-null     str
#  14  Telefono              52 non-null     str
#  15  TotalReportado        51 non-null     float64
# ...

# %%
# Mostrar estadísticas generales
df.describe()
# Out:
#        TotalReportado
# count       51.000000
# mean      3930.549020
# std       4618.437888
# min       -500.000000
# 25%        956.250000
# 50%       2375.000000
# 75%       3900.000000
# max      15000.000000

# %%
# Mostrar cantidad de valores nulos por columna
df.isnull().sum()
# Out:
# IdVenta                  0
# FechaVenta               1
# ClienteId                1
# ClienteNombre            1
# Ciudad                   1
# Producto                 0
# Categoria                0
# Cantidad                 1
# PrecioUnitario           1
# Descuento                1
# MetodoPago               0
# Estado                   1
# Vendedor                 0
# EmailCliente             1
# Telefono                 0
# TotalReportado           1
# Observaciones_Origen    15
# dtype: int64

# %%
# Mostrar filas que contienen valores nulos
filas_nulas = df[df.isnull().any(axis=1)]

filas_nulas
# Out:
#    IdVenta           FechaVenta ClienteId        ClienteNombre  \
# 0   V-1001  2026-05-01 00:00:00      C001            Ana López
# 2   V-1002           01/05/2026      c002         Carlos Mejía
# 5   V-1005                  NaN      C005         Sofia García
# 7   V-1007           2026-05-04       NaN  Cliente Desconocido
# 15  V-1015           2026-05-08      C015         Oscar Valdez
# 17  V-1017           2026-05-09      C017         Laura Zuniga
# 18  V-1018           2026-05-10      C018          Kevin Pinto
# 20  V-1020           2026-05-11      C020        Rosa Martínez
# 21  V-1021           2026-05-11      C021        Pedro Aguilar
# 23  V-1023           2026-05-12      C023        Andrés Molina
# 28  V-1028           2026-05-14      C028         Valeria Cano
# 30  V-1030           2026-05-15      C030          Monica Díaz
# 31  V-1031           2026-05-16      C031          Ruben Ochoa
# 34  V-1034           2026-05-17      C034        Noelia Torres
# ...

# %%
# Mostrar filas duplicadas
duplicados = df[df.duplicated()]

duplicados
# Out:
# Empty DataFrame
# Columns: [IdVenta, FechaVenta, ClienteId, ClienteNombre, Ciudad, Producto, Categoria, Cantidad, PrecioUnitario, Descuento, MetodoPago, Estado, Vendedor, EmailCliente, Telefono, TotalReportado, Observaciones_Origen]
# Index: []

# %% [markdown]
# # Problemas encontrados
#
# - Se encontraron valores nulos en algunas columnas.
# - Existen filas duplicadas.
# - Algunos datos presentan inconsistencias.
# - La calidad de la data necesita limpieza antes del análisis.

# %%
# Eliminar filas duplicadas
df = df.drop_duplicates()

# %%
# Rellenar valores nulos con 0
df = df.fillna(0)

# %%
# Contar valores nulos por columna
nulos = df.isnull().sum()

# Crear gráfico de barras
plt.figure(figsize=(10,5))

plt.bar(nulos.index, nulos.values)

# Título del gráfico
plt.title('Valores nulos por columna')

# Rotar nombres de columnas
plt.xticks(rotation=45)

# Mostrar gráfico
plt.show()

# %%
# Mostrar la data limpia
df.head()
# Out:
#   IdVenta           FechaVenta ClienteId ClienteNombre          Ciudad  \
# 0  V-1001  2026-05-01 00:00:00      C001     Ana López     Tegucigalpa
# 1  V-1001  2026-05-01 00:00:00      C001     Ana López     Tegucigalpa
# 2  V-1002           01/05/2026      c002  Carlos Mejía  San Pedro Sula
# 3  V-1003           2026/05/02      C003  María Santos             SPS
# 4  V-1004         mayo 3, 2026      C004   Jose Rivera        La Ceiba
#
#   Producto   Categoria Cantidad PrecioUnitario Descuento     MetodoPago  \
# 0   Laptop  Tecnología        1          14500      0.05        Tarjeta
# 1   Laptop  Tecnología        1          14500      0.05        Tarjeta
# 2    mouse  tecnologia        2      L. 350.00         0       efectivo
# 3  Teclado  tecnologia        1         450,50        5%  Transferencia
# 4  Monitor  Tecnología        0           3200         0        Tarjeta
#
#       Estado   Vendedor              EmailCliente   Telefono  TotalReportado  \
# ...

# %%
df.to_excel('../data/processed/Data_Limpia_Ventas.xlsx', index=False)
